# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

url = "https://lnb.com.br/nbb/estatisticas/pontos/"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")
table = soup.find(name="table")

table_str = str(table)
df = pd.read_html(table_str)[0]

df["jogador"] = df["Jogador"].apply(lambda x: x.split(" #")[0])
df["numero"] = df["Jogador"].apply(lambda x: x.split(" #")[1])
df.drop(columns=["Jogador", "Pos."], inplace=True)

df.rename(
    columns={
        "Equipe": "equipe",
        "JO": "jogos",
        "Min": "minutos",
        "Pts": "pontos",
        "3P": "media_tres_pontos",
        "2P": "media_dois_pontos",
        "LL": "media_lance_livre",
    },
    inplace=True,
)

df = df[
    [
        "jogador",
        "numero",
        "equipe",
        "jogos",
        "minutos",
        "pontos",
        "media_tres_pontos",
        "media_dois_pontos",
        "media_lance_livre",
    ]
]

# %%
from csv import Error
from tkinter import E
from bs4 import BeautifulSoup
import requests
import pandas as pd

params = {"v": "1735051758988"}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

url = "https://lnb.com.br/nbb/estatisticas/pontos/"
r = requests.get(url, params=params, headers=headers)
print(r.url)
if r.status_code == 200:
    print(r.json())
    # soup = BeautifulSoup(r.content, "html.parser")
    # table = soup.find(name="table")
    # table_str = str(table)
    # df = pd.read_html(table_str)[0]
    # print(df.head(10))
else:
    print("Erro ao acessar a página")
# Out:
# https://lnb.com.br/nbb/estatisticas/pontos/?v=1735051758988
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.17/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.pyenv/versions/3.9.17/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
df.head()
# Out:
#    Pos.       Jogador                   Equipe  JO    Min    Pts     3P  \
# 0     1      Brite #3             Bauru Basket  17  31.60  21.41   9.00
# 1     2  Sifontes #23                 Botafogo   3  31.38  21.00   6.00
# 2     3       Cook #7  CAIXA/Brasília Basquete   9  31.20  20.67  10.67
# 3     4    Barnes #34            Pato Basquete  17  31.14  18.35   6.35
# 4     5    Wesley #21              Sesi Franca   6  26.74  17.50   0.00
#
#       2P    LL
# 0   8.24  4.18
# 1  10.00  5.00
# 2   6.22  3.78
# 3   9.06  2.94
# 4  14.67  2.83
